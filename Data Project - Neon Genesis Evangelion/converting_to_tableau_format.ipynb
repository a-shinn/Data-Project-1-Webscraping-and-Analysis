# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Converting data from wide to long for easier Tableau visualization

# %%
# importing datasets from saved JSON files
entire_series = pd.read_json('src/NGE_entire_series.json')
by_episode = pd.read_json('src/NGE_by_episode.json')

# %%
by_episode
# Out:
#                                                               1   \
#                {'Lines': ['#The Traffic panel shows "Tokyo-3:...
# Aircraft       {'Lines': ['Aircraft: Ah!  '], 'Line Count': 1...
# Announce       {'Lines': ['Announce: The gate is closing. Att...
# Cmdr-in-Chief  {'Lines': ['Cmdr-in-Chief: You are the command...
# Female Voice   {'Lines': ['Female Voice: The identifiable mov...
# ...                                                          ...
# A boy                                                       None
# Kaoru                                                       None
# Father                                                      None
# Kyouko                                                      None
# Step mother                                                 None
#
#                                                               2   \
#                {'Lines': ['#The cover of the report says:    ...
# Aircraft                                                    None
# Announce                                                    None
# Cmdr-in-Chief                                               None
# Female Voice                                                None
# ...                                                          ...
# A boy                                                       None
# Kaoru                                                       None
# Father                                                      None
# Kyouko                                                      None
# Step mother                                                 None
#
#                                                               3     4     5   \
#                {'Lines': ['#JAPANESE GREETING LESSON: We alwa...  None  None
# Aircraft                                                    None  None  None
# Announce                                                    None  None  None
# Cmdr-in-Chief                                               None  None  None
# Female Voice   {'Lines': ['Female Voice: Now, a state of spec...  None  None
# ...                                                          ...   ...   ...
# A boy                                                       None  None  None
# Kaoru                                                       None  None  None
# Father                                                      None  None  None
# Kyouko                                                      None  None  None
# Step mother                                                 None  None  None
#
#                                                               6   \
#                                                             None
# Aircraft                                                    None
# Announce       {'Lines': ['Announce:Enemy's particle accelera...
# Cmdr-in-Chief                                               None
# Female Voice                                                None
# ...                                                          ...
# A boy                                                       None
# Kaoru                                                       None
# Father                                                      None
# Kyouko                                                      None
# Step mother                                                 None
#
#                                                               7     8     9   \
#                                                             None  None  None
# Aircraft                                                    None  None  None
# Announce       {'Lines': ['Announce: Unit One has cleared the...  None  None
# Cmdr-in-Chief                                               None  None  None
# Female Voice                                                None  None  None
# ...                                                          ...   ...   ...
# A boy                                                       None  None  None
# Kaoru                                                       None  None  None
# Father                                                      None  None  None
# Kyouko                                                      None  None  None
# Step mother                                                 None  None  None
#
#                  10  ...                                                 17  \
#                None  ...                                               None
# Aircraft       None  ...                                               None
# Announce       None  ...  {'Lines': ['Announce: The transformation of th...
# Cmdr-in-Chief  None  ...                                               None
# Female Voice   None  ...                                               None
# ...             ...  ...                                                ...
# A boy          None  ...                                               None
# Kaoru          None  ...                                               None
# Father         None  ...                                               None
# Kyouko         None  ...                                               None
# Step mother    None  ...                                               None
#
#                  18                                                 19    20  \
#                None                                               None  None
# Aircraft       None                                               None  None
# Announce       None  {'Lines': ['Announce: Right now, the emergency...  None
# Cmdr-in-Chief  None                                               None  None
# Female Voice   None                                               None  None
# ...             ...                                                ...   ...
# A boy          None                                               None  None
# Kaoru          None                                               None  None
# Father         None                                               None  None
# Kyouko         None                                               None  None
# Step mother    None                                               None  None
#
#                  21                                                 22  \
#                None                                               None
# Aircraft       None                                               None
# Announce       None  {'Lines': ['Announce : Medical Staff meeting f...
# Cmdr-in-Chief  None                                               None
# Female Voice   None                                               None
# ...             ...                                                ...
# A boy          None                                               None
# Kaoru          None                                               None
# Father         None                                               None
# Kyouko         None                                               None
# Step mother    None                                               None
#
#                                                               23  \
#                                                             None
# Aircraft                                                    None
# Announce       {'Lines': ['Announce:       Unit Two, To the e...
# Cmdr-in-Chief                                               None
# Female Voice                                                None
# ...                                                          ...
# A boy                                                       None
# Kaoru                                                       None
# Father                                                      None
# Kyouko                                                      None
# Step mother                                                 None
#
#                                                               24  \
#                                                             None
# Aircraft                                                    None
# Announce       {'Lines': ['Announce:       Central Dogma is b...
# Cmdr-in-Chief                                               None
# Female Voice                                                None
# ...                                                          ...
# A boy          {'Lines': ['A boy:          hmmmm,,mmm        ...
# Kaoru          {'Lines': ['Kaoru:          You are, the First...
# Father                                                      None
# Kyouko                                                      None
# Step mother                                                 None
#
#                                                               25    26
#                                                             None  None
# Aircraft                                                    None  None
# Announce                                                    None  None
# Cmdr-in-Chief                                               None  None
# Female Voice                                                None  None
# ...                                                          ...   ...
# A boy                                                       None  None
# Kaoru                                                       None  None
# Father         {'Lines': ['Father:         Well,             ...  None
# Kyouko         {'Lines': ['Kyouko:         Your daddy now hat...  None
# Step mother    {'Lines': ['Step mother:    A Doctor is a huma...  None
#
# [136 rows x 26 columns]

# %%
def get_long(name):
    df = pd.json_normalize(by_episode.T[name])
    df['Index'] = pd.Index(range(1,27))
    df.set_index('Index', inplace=True)
    #
    dfm = df.melt(ignore_index=False)
    return dfm

# %%
new_file = pd.concat([get_long('Shinji'),
           get_long('Asuka'),
           get_long('Misato')])

# %%
new_file
# Out:
#          variable                                              value
# Index
# 1           Lines  [Shinji: Out of order ... I shouldn't have com...
# 2           Lines  [Shinji: I prefer to being alone. Any places a...
# 3           Lines  [Shinji: Switch ......  , Shinji: Aim at the t...
# 4           Lines  [Shinji: That isn't the question. Anyhow, it's...
# 5           Lines  [Shinji: We hardly speak to one another.  , Sh...
# ...           ...                                                ...
# 22     Word Count                                                433
# 23     Word Count                                                166
# 24     Word Count                                                264
# 25     Word Count                                                500
# 26     Word Count                                                144
#
# [234 rows x 2 columns]

# %%
new_file.to_excel('src/longformat_data.xlsx')
