# %% [markdown]
# # **Webscraping the script of Neon Genesis Evangelion**

# %%
import pandas as pd
import bs4 as bs
import requests
import re
import time

# %% [markdown]
# In this notebook, I'll be pulling scripts from each episode of Neon Genesis Evangelion using the BeautifulSoup and Requests packages and parsing through for each separate line of dialogue using regular expressions. I created two separate dictionaries to track the number of times each character speaks and their word count. The first dictionary covers character lines and word count for the entire series, and the second is a dictionary of dictionaries which contains the same data, but for a given episode and the characters in that episode.
#
# To get the scripts I'll be using for this analysis, I'll be pulling from scripts available online at https://www.animanga.com/scripts/anime_scripts_english.html. The urls follow a pattern in naming conventions, so I can pull each episode script sequentially with a loop.

# %%
character_lines = {}
lines_by_episode = {}


for i in range(1,27):
    current_ep = {}

    webpage = requests.get(f'https://www.animanga.com/scripts/textesgb/eva{i}.html')
    soup = bs.BeautifulSoup(webpage.text, 'lxml')
    page_text = soup.get_text()

    #------------------------------------------------------------------------

    regex = re.compile(r"(?m).+:[^*#:]+\n (?:(?![#*]).)*") # regular expression to match each separate line of dialogue
    result = re.findall(regex,page_text)

    #------------------------------------------------------------------------

    # iterating through each line of text, creating a key and word count
    # if character not already in character_lines, otherwise adding to the existing entry
    for text in result:
        character_name = re.findall('[^:#]*',text)[0] # regex to pull the name of the character speaking
        character_name = character_name.strip('!"#$%(*+, ''-./:;<=>?@[\]^_`{|}~') # stripping leading + trailing punctuation
        word_count_line = len(text.split())-1
        text=text.split('------------')[0].split('----------------------')[0].split('-----------------------------------------------------------------------')[0].split('-------------------------------------------------------')[0].split('--------------------------------------------------------------------')[0].replace('\n','').replace('\r','')
        if character_name in character_lines:
            character_lines[character_name]['Lines'].append(text)
            character_lines[character_name]['Line Count'] += 1
            character_lines[character_name]['Word Count'] += word_count_line
        else:
            character_lines[character_name] = {}
            character_lines[character_name]['Lines'] = []
            character_lines[character_name]['Lines'].append(text)
            character_lines[character_name]['Line Count'] = 1
            character_lines[character_name]['Word Count'] = word_count_line

    for text in result:
        character_name = re.findall('[^:#]*',text)[0] # regex to pull the name of the character speaking
        character_name = character_name.strip('!"#$%(*+, ''-./:;<=>?@[\]^_`{|}~') # stripping leading + trailing punctuation
        word_count_line = len(text.split())-1
        text=text.split('------------')[0].split('----------------------')[0].split('-----------------------------------------------------------------------')[0].split('-------------------------------------------------------')[0].split('--------------------------------------------------------------------')[0].replace('\n','').replace('\r','')
        if character_name in current_ep:
            current_ep[character_name]['Lines'].append(text)
            current_ep[character_name]['Line Count'] += 1
            current_ep[character_name]['Word Count'] += word_count_line
        else:
            current_ep[character_name] = {}
            current_ep[character_name]['Lines'] = []
            current_ep[character_name]['Lines'].append(text)
            current_ep[character_name]['Line Count'] = 1
            current_ep[character_name]['Word Count'] = word_count_line

        # ------------------------------------------------------------------------

    lines_by_episode[i] = current_ep

        # there shouldn't be a risk of overloading the server, but added a short wait in between URL requests just in case
#     time.sleep(1)

# %% [markdown]
# Looking through the compiled list of characters and lines, there are clearly a lot of typos, ranging from misspelled names, to translator notes being included, to whitespace or punctuation causing errors in dialogue attribution.
#
# Next steps in order:
#
# 0. Done in the previous step: leading punctuation and whitespace was stripped so that names with errors (ex: 'Shinji' and '  Shinji  ') are counted for the same key in each dictionary.
#
# 1. Removing "names" which only appear due to being in the translator notes on each page and sorting dictionaries alphabetically.
#
# 2. Converting dictionaries into dataframes

# %%
# entire series: dictionary - {character name:[line count, word count]}
sorted_lines = dict(sorted(character_lines.items())) 

# individual episodes: dictionary of dictionaries - {episode number: {character name:[line count, word count]}}
sorted_eps = {}
for i in range(1,27):
    sorted_eps[i] = dict(sorted(lines_by_episode[i].items())) 

    #------------------------------------------------------------------------

# # filtering out common translator notes not in the script
filter = ['Neon','EVA','Email','E-mail','http','title','episode','Episode','EPISODE','Nadia','Movie','Preview','Trail','0','4']

for i in range(1,27):
    sorted_eps[i] = {k:v for k, v in sorted_eps[i].items() if not any(x in k for x in filter)}

sorted_lines = {k:v for k, v in sorted_lines.items() if not any(x in k for x in filter)}

sorted_lines['Misato']
# Out:
# {'Lines': ['Misato: Why, of all times, have I missed him at such a time?! ......   What am I going to do?      ',
#   "Misato: Hey! It can't be... Are they going to use a N2-mine?! Lie   down!  ",
#   'Misato: Here goes!  ',
#   "Misato: Sure. Don't worry. He is under my protection at top priority.   Prepare a car train for us. A linear one, please. Yes. I'll bear   the full responsibility for him because it was my idea to meet him   in the first place. Bye. ",
#   "Misato: Ah, It's OK. No problem. It is during an emergency... We   can't do anything if the car doesn't run. In the addition, I am an   international officer even if I don't seem like it. ",
#   'Misato: Uninteresting boy. You look so calm, very unlike your pretty   face. ',
#   "Misato: Hmm, are you angry? Sorry, I'm sorry. It's natural because   you a boy. ",
#   'Misato: Yes, the secret organization directly attached to the United   Nations. ',
#   'Misato: Thanks!      ',
#   'Misato: Then, read this.      ',
#   'Misato: I know. You consider him to be a tough customer. Me too.  ',
#   "Misato: That's right. This is our secret base, Nerv Headquarters.   It's also the foundation for rebuilding the world and the fort for   the human race. ",
#   "Misato: That's strange. I'm sure this is the right way ...      ",
#   "Misato: I'd really rather not wear a skirt this place. Anyway, where   has Ritsuko gone? Sorry that I'm not familiar with this place. ",
#   "Misato: He is very much like his father ...... in that they aren't   lovable. ",
#   'Misato: It\'s only a number. Anyway, to say "It doesn\'t work at all"   ... will be no excuse. ',
#   "Misato: Sally?! Unit Zero is being frozen... No kidding ... Do you   mean that you'll activate Unit One? ",
#   'Misato: But, even in the case of Rei, it took seven full months for   her to synchronize with Eva. ',
#   "Misato: Shinji-kun... Why did you come here? Don't run away, from   your father, above all from yourself. ",
#   'Misato: It reacts without the interface... Or rather, did it protect   him? ... He can do it!  ',
#   'Misato: Ready for launching.  ',
#   'Misato: Launch! ',
#   "Misato: The announcement was 'Scenario D-22'. The facts were hushed    up again.",
#   "Misato: I always think that an air conditioner is the greatest treasure of    the human! It's really a scientific success!",
#   'Misato: See you.',
#   "Misato: As I said now, I've decided to take charge of Shinji-kun. I've    got the superior's agreement. Don't worry. I won't have an affair with    the child.",
#   "Misato: Of course, it's a welcome party for a new lodger!",
#   "Misato: This is the Fortress City for Intercept against ANGELs 'Tokyo-3'   ...... Our hometown ...... and the town which you protected.",
#   "Misato: We've finally found something completely outside our experience,    haven't we? ",
#   'Misato: Say! You might say nothing\'s wrong, but you seem to say "Take care   of me. Worry about me, please."',
#   'Misato: Ah, me?  Heheh (giggling) ... Jaaan(fanfare). Put that into this.    Dobaaatto (Drastically)!',
#   "Misato: Why, this is quite good. I can't make such a good taste with   a curry-flavored cupnoodle. ITADAKIMASU. I don't put in too much soup    and hot water. It's a knack!     ",
#   "Misato: He's right, Ritsuko. Don't make light of humans' ability   to adapt to their environment. Besides, if he does move... ",
#   "Misato: Now you have an official excuse to go Rei's home. It's a good   chance, don't you think? ",
#   'Misato: Shinji-kun! ',
#   "Misato: Both offense and defence are very slick...         The thing's a flying fortress.         And the enemy Shield?",
#   "Misato: Shit!        And what's its ETA (Estimated Time of Arrival)?",
#   'Misato: --impossible?        How is the pilot of Unit One?',
#   "Misato: Yes.        A single point attack with a high energy convergence unit, without        first neutralizing the target's AT-field.  There's no other way.",
#   'Misato: The answers from Supercomputer Magi were 2 affirmative and 1        conditional affirmative.',
#   '(Misato: Two of the Magi supercomputers say it can work, while the         third gives a conditional affirmative.)',
#   "Misato: Don't be rude! It's not insane--it can be carried out within 9         hours and has the highest chance of success.",
#   "Misato: Yeah. The SSDF (Strategic Self Defense Force) Lab's prototype.",
#   'Misato: For this reason, we, the Special Institute Nerv, hereby requisition         this automatic positron cannon from 15:00 today.',
#   'Misato: We will do our best to return this in its original condition.        Thank you very much for your cooperation.',
#   "Misato: Okay, Rei, take this.        It's a delicate machine, so be careful...",
#   "Misato: That's settled! From all over Japan.  ",
#   'Misato: Excellent!        All right, the attack will be from the top of Mt. Futagoyama.        The operation will commence at 0:00 AM, midnight.',
#   'Misato: Here are the arrangements for the operation.        Shinji-kun--',
#   'Misato: You will be the gunner.        Rei, you will defend him with Unit Zero.',
#   "Misato: Shinji-kun, you're using energy from all over Japan.        Hang in there!",
#   'Misato: The anti-Angel humanoid robot developed by civilians goes        wild and Misato must stop its reactor meltdown.        Next episode is "Human works".        Looking forward to watching it!',
#   "Misato: A Japanese style morning always begins with steamed rice,        miso-soup, and sake! It's been tradition for many years...",
#   'Misato: Well, ironic... Okay, so now he feels at home, and can express        himself more than before.',
#   "Misato: Yeah. And we should complain about the budget--humanity's         destiny rests on this system.",
#   "Misato: I'm going to Ex-Tokyo on business. I'll be back late.        You should eat out tonight.",
#   "Misato: There's no reason to do that here. And the SSDF has something         to do with this project?",
#   "Misato: Eh, this is total bullshit.  Those bastards are...        Maybe this is revenge from those who failed to get Nerv's         acquisitions. This is pissing me off! Those guys...! Phew...",
#   "Misato: Stop! It's childish. So proud of himself, wanting to be        appreciated... He's not worthy of the attention.",
#   'Misato: No. There must be a way to reset everything--the ultimate method        of stopping it. Give me the password to do that.',
#   "Misato: We can't wait that long! After the explosion, it will be         too late!",
#   "Misato: Hey, Hyuga-kun? People in Atsugi know what I am going to do.        Send Shinji-kun and Unit One with F equipment here...        Yes, it's an emergency.",
#   "Misato: The target is JA. There's a danger of meltdown in 5 minutes.        We cannot allow that in a populated area. Hyouga-kun?",
#   'Misato: Run with the target, and then put me on the back.        Then hold the target motionless.',
#   "Misato: Well, I have to do what I can. Otherwise, I'll regret it         forever.",
#   'Misato: Let me introduce you--this is the exclusive pilot ofEvangelion Unit Two, the Second Child, Soryu Asuka Langley.',
#   "Misato: Considering Eva's importance, it still seems lacking.        Well, please sign these forms.",
#   'Misato: Hi, Nerv Delivery!  You ordered data on and countermeasures        against this invisible enemy, right?',
#   "Misato:What are you talking about? This is an emergency!       Your orders don't matter!",
#   'Misato: Yes. We evacuate two battleships and sink them on the axial         line of the Umbilical Cable to form a trap.        Meanwhile, Eva Unit Two will open the mouth of the target. The        ships will then rush into the opening, fire with their bow        turrets, and then self-destruct. That way the target will be        totally defeated.',
#   'Misato: He escaped earlier and must already have arrived at HQ.        That bastard!',
#   "Misato: He's long since been silly.        Your business to bring here Unit 2 is complete.        You must go home!",
#   'Misato: Who would do with you!        WOW, Enemy Attack!',
#   'Misato: The intercept system of Third New Tokyo city was heavily damaged        by the privious battle. Only 26% has been restored.        Operatable equipment at the actual battle is almost Zero.        Thus, we beat the target before that land at the waterfront.        Unit 1 and Unit 2 countinal attack in turn.        Close battle!',
#   'Misato: I know what\'s are written without reading.        They say "if battle, do here."',
#   'Misato: I will do the setlement of angels here.        I will beat that angel!',
#   'Misato: You must be kind enough to bring me some good idea for me        to avoid being sacked.',
#   'Misato: You are great! Dr. Akagi Ritsuko. Good to have is a kind        old friend.',
#   "Misato: The seventh Angel has only one weakpoint.        The heavy two point attack to the core during the separation.        That's the only way.        In other words, an attack by two Evas at the complete        syncronized timing.",
#   "Misato: NO! I don't accept. You know, Man and Woman must not live together        after 7 years old. That's the proverb.",
#   'Misato: The angel is on the self-restoration.        The second attack is predicted 6 days later. We have no time.',
#   'Misato: Well, the way to realize the insane thing is        to master the attack pattern harmonized to this music.        In six days. as soon as possible!',
#   "Misato: This way, we'd better to change the plan and you'd better make a pair        with Rei.",
#   'Misato: No. you are no longer my something.        I beg you not to do this again.',
#   "Misato: Bhhh, Don't say such a thing. Who love that kinda guy!        No matter how I was young, it was my biggest taint ever in my",
#   'Misato: Nothing different. He is still immature.        Here I go, business, business. Tomorrow is the day of final battle!',
#   "Misato: The guy comes! We'll not fail this time.        When the music starts, you expand AT field.        Then, do according to the plan. You two, ready?",
#   'Misato: Go!',
#   "Misato: I know how you wanna go, but there's no other way.        An angel would likely to attack us during your absence for the        excursion.",
#   "Misato: If we could, we would do that.        Well, you must think it's a good chance.        While others are going for the excursion, you can study.        Do you think I am ignorant of this?",
#   'Misato: You must know I know all without your confession.        I can easily access the information on the result of the exams.',
#   'Misato: In Rome, do as romans do.        I hope you are used to the school life in Japan.',
#   "Misato: No doubt. That's an Angel.        This lab. is completely closed from now on.        And is under Nerv's control.        No entry to the room is permitted, and all the events of last 6 hours        are secret to outside.",
#   'Misato: Two Units wait at the position.        Hurry prepare for laser shot and crane.',
#   'Misato: Roger.        Asuka, are you ready?',
#   'Misato: Hurry up Re-calculation! Operation continued.        Descend farther.',
#   'Misato: Not yet encountered the target. Continue.        Asuka, how about the status?',
#   'Misato: Although our damage resultant was terribly large,',
#   'Misato: the challenge of the unexperienced boy         to the first battle against the unknown target',
#   'Misato: and the fact that he carried out the challenge        were indeed admirable deeds of Ikari Shinji.',
#   'Misato: However, for the section of planning, it was a hard        battle that revealed further more problems and many        points to improve.',
#   "Misato: Unit Zero for the first time, because it's different Eva,        it's reasonable.",
#   'Misato: This incident has something to do with that incident of going wild?        That incident of Rei?',
#   'Misato: As the planning manager, I request you to do it immediately,        before that troubles our job.',
#   "Misato:         Oh, you mean the wedding party?                I had on that suits in pink at Kiyomi's party.                I just recently had on that dress in navy-blue at Kotoko's.",
#   "Misato:         That's right.                Phew.                Should I buy new one on the way home?                That will cost a lot.",
#   'Misato:         Shit! Every one is eager to marry before they get                thirty years old.',
#   "Misato:         That's not for you, a child.                Shinji-kun is in his room?",
#   "Misato:         You are afraid of that? To be with your father alone?                It's no good to always escape.                You must go one step further.                Otherwise nothing will change.",
#   'Misato:         You are going to know,                Not only the first step, but also you have to continue                to step after the first one.                Anyhow, you must go there with the strong mind tomorrow,                since you will meet your mother.',
#   "Misato:         Anyhow, why don't you shave that sloppy beard?                 And the tie is not set correctly.",
#   "Misato:         It's too late to say such a thing.                I'll fix my hear.",
#   'Misato:         I am sorry that I insisted to separate at that time.                I told you that I had another one to love,                yet it was a lie.                Did you find that?',
#   "Misato:         I found, I found that you had something that resembled to my                father.                I was looking for the appearence of my father. When I found                that, I feared. I feared everything.                I feared to be with you.                I feared to be a woman. I feared everything.                Although I'd hated my father,                I happened to love a man looking like my father.",
#   'Misato:         To forget everything, I joined NERV, which, however, was an                institute at that my father had been.                I have been pretending to revenge Angels.                Phew.',
#   "Misato:         No! I did not choose that way. I just tried to escape.                I just tried to escape from my father's spell.                Just like Shinji-kun.                I am cowardly.                I am sorry.                 Tonight, I'm speaking this kind a thing because I am drunk.                ",
#   'Misato:         And moreover, I try to depend on a man only in such a situation                like this. I am a foul woman.                At that time, I might have made use of you.                I hate myself!',
#   'Misato:         I despair of myself!                uuh...',
#   'Misato:         Is this your true job?                Or part-time job?',
#   "Misato:         The person belonging to the special section of inspection,                of the special institute NERV is Kanji Ryouji,                at the same time, you are a person belonging to                the inquiry section of the Japan's ministry of interior,                Kaji Ryouji.",
#   'Misato:         On my own accord. If you do this part-time job further,                you shall die.',
#   "Misato:         Since I appreciate your yesterday's matter,                I allow you about that.",
#   'Misato:         This is...                Eva?...                No,..                Is this...',
#   "Misato:         Adam?                That first Angel is here?                Well, NERV is less cheaper than I've held",
#   "Misato : Oh,oh.That's Shin-chan's life-style. ",
#   'Misato : Shut up. ow!        Well,how about the Third Children?        ',
#   'Misato : Well.        Wow,(looking at the monitor) I hope he gains confidence         to know this.        ',
#   "Misato : Ah, sorry.        What's going on? The observation centre of Mt.Fuji did ...        ",
#   "Misato :Can you hear me?        Target's data are those I've sent.        Presently, we don't have further data.        Approach carefully, watch its reaction,        and If possible, lead it to outside the urban area.",
#   "Misato : Stop, you people.        Yes, he acted arbitrarily without consultation.        So I'll have to scold him when he's back.        ",
#   'Misato : Forced salvaging Eva ? ',
#   "Misato : But, you know, how Eva's body, eee,        will be. Heck,         It's not the rescue operaion.        ",
#   "Misato : What's the reason why you and the commandor Ikari        stick on the Unit One ?        Huh, what is Eva ?        ",
#   "Misato : (thought) I understand that EVA isn't just a copy of         the First Angel, though, how is NERV going to use EVAs        after it defeats all Angels ?        ",
#   'Misato : Shinji-kun, Shinji-kun, Shinji-kun!-        Shinji-kun, are you alright ? Shinji-kun!!        (weep)        ',
#   "Misato: Yes.        His emotion is very unstable.        I don't think it's a good idea that he stands here at the moment.",
#   'Misato: The report from the experiencee does not suggest that.        Presumably, it was an irregular incident.',
#   'Misato: I am not able to answer that question.        Do Angels have the concept of mind?        Do they understand human thoughts?        Those are absolutely unknown.',
#   'Misato: Considering the patterns so far,        the systematic coupling among the Angels is negative.',
#   'Misato: As for the Unit three and four, they insisted the right        of the construction, and forced to build them.        But, now, they force us to accept that.        They push their luck.',
#   "Misato: Then, how to do the booting test?        using Rei's dummy?",
#   'Misato: The Fourth?        The fourth children was found?',
#   'Misato: Well, OK.        And, who is the selected child?',
#   "Misato: It's hard to tell this.        Asuka is OK. She is proud of pilotting Eva.        Rei is exceptional.        Nothing good if concerned with Eva things and our matters.        It is Shinji that knows these matters best.        I don't want him to be more painful.",
#   "Misato: Although I don't say anything about your private life,        I beg you not to seduce young girls here in this emergent        situation.",
#   'Misato: It depends on your answer you are about to say.        You must know the secrets of Malduk Institute and ADAM         underground.',
#   "Misato: I don't care a bit what people say about me.        I am not reserved at the moment.        Timely the fourth children was found.        What is the hidden reason for that?",
#   'Misato: Nothing but NERV?        Commander Ikari?',
#   "Misato: Seven O Seven?        Shinji-kun's school?",
#   'Misato:That was true.  Unit 4 is gone with the NERF 2nd Branch.  During the        test of S2 Engine.        We are OK here. All three units are working OK. Both the pilots and        the staffs are excellent, too.',
#   "Misato: Mmmm, I'll leave the house for about 4days, but don't warry since        Kaji will take care of you guys.",
#   "Misato: I just can't find a chance to say that.  I'm afraid since I can't         figure out what he is thinking about.",
#   'Misato: Late for two hours, and at last, he is here.        He is the first guy to make me wait this long.',
#   'Misato: Exclusive possession of four EVAs...  If we want, we can ends this         world.',
#   'Misato: Alive...        Kaji....?',
#   'Misato: The pilot for the Unit 3 is,        The 4th Children is',
#   "Misato:   There is no problem in so far as I can work.          I just can't be off in this state of emergency.          What happened to Shinji-kun?",
#   'Misato:   I think you know, but there will be a fair amount of restrictions          on your behavior.',
#   'Misato:   The fourth level candidates are all your class mates.          I learned that recently too.          It was all contrived.',
#   "Misato:   As for Suzuhara-kun's matter,          it's not a mistake recovered by apologizing with any words.          But Shinji-kun, to be honest, I was projecting my dream,          hope and purpose upon you.          I know it's been a load to you.          But we, everyone at NERV, had no choice but to trust our           future to you.          Just remember that, please.",
#   "Misato:   I know that.          I'll leave your pass-code up to the headquarters and your room          as they are.",
#   "Misato:   (He's speaking positively [in his own words].           It's the first time to hear something like this.)",
#   'Misato:   Post Unit Two in the Geofront,          on the rim of the Headquarters facilities.-          Let Asuka snipe the target at the instant it invades into theGeofront!-          The Unit Zero status?',
#   'Misato:   Asuka!          Cut all the nerve connection.  Fast!',
#   "Misato:   It's coming here.          All personnel to be evacuated.  Fast!",
#   "Misato: Only with the visible situations, we can't decide how we   should do with it. ",
#   "Misato: I can't believe it! What the hell is the matter with   Shinji-kun? ",
#   "Misato: Created by humans? You only make a copy of what you pick up   on Antarctica then. Original? I'm dumbfounded. ",
#   "Misato: Do something! You made that, didn'd you? Take the   consequences! ",
#   "Misato: I don't know. What Nerv want isn't his life but Unit One as   their tool. ",
#   "Misato: You mean that Shinji has transformed into something which we   can't identify visibly? ",
#   "Misato: You're saying about the theory, aren't you? Nobody knows the   results without doing. ",
#   "Misato: I'm kind to you. Well, Shinji-kun. Do you want to become one   with me? Do you want us to become one both mentally and   physically? That's so comfortable. I'm ready. I'm always ready. ",
#   "Misato: Shinji-kun, you are here because you got into Eva. Because   you got into Eva, you became what you are. You can't deny that,   the fact that you got into Eva nor what you were, your past life. ",
#   "Misato: (wailing) What a nonsense the science which can't save even a   person. ",
#   "Misato: Human-made-human Evangelion. Although it was made by humans,   don't you think the black box is too large? I'm satisfied because   Shinji-kun was finally saved. ",
#   "Misato: Others ... I'm right? You aren't interested in others but you   feel lonely. You're really like my father. ",
#   "Misato: At present, it's important that I let you know my hope. What   is the true goal of Nerv and Commander Ikari? ",
#   "Misato: Wait, dodge my questions by doing such a thing. No, don't put   such a thing in. Well, what are you doing in such a time? ",
#   'Misato:         Hello, I am absent at the moment. Please leave your message                after a tone signal.',
#   "Misato:         That's inside of this installation.                You, people of the division of intelligence, did nothing                against that?",
#   'Misato:         The guy who can baffle the Second section of Intelligence                division.                That is, ',
#   'Misato:         Considering the carrier of me and him, this is a quite natural                consequence.',
#   'Misato:         I still hate darkness.                That reminds me of notthig but horrible things.',
#   'Misato:         Yeah, Katsuragi Misato, Nice to meet you.',
#   'Misato : (monologue)              (What was born from Adam, that is series of Evas.               We  have no other way to defeat the Angels without utilizing the               very cause which lead to the Second Impact.               In other words, those who utilize even the thing that triedto destroy              themselves, they are the human beings.)',
#   'Misato : They started the construction of the Evas until Number  13 ?             In seven places all over the world ?',
#   'Misato : Why they hurry up building in this time ?                   ',
#   'Misato : Who knows ?             Even for us, we got the parts from Germany which were             originally made for Unit-5 and 6.             Nowadays they spend much money.',
#   'Misato : Hooom...    But there are no reason for them to do             informally.   There should be another aim.',
#   "Misato :   Although it's been long since we were together last.                But what is this unsociable atmosphere ?",
#   'Misato : Asuka is under a bad condition.  She is during the second             day of that .',
#   "Misato : It's a natural course, after beaten in that way.             Moreover, much worse is that she feels as she was                                 beaten by Shinji.             Maybe it's our limitation.  I'm afraid we three could not             live together.",
#   "Misato : I won't allow to say that phrase from you who conceal her             loneliness with cats.",
#   "Misato : Oh, I am very sorry !             I'm slightly upset.",
#   'Misato : That means,  that is waiting for the chance of             coming down, or that is going to destroy us without             approaching ?',
#   "Misato : Anyway, we can do nothing  unless that approaches to              within our firing range.             Eva cannot beat the enemy over the satellite orbit.             How's Rei  ?",
#   'Misato : Roger.   Unit-0, Sortie!  Prepare for the very-long-             distance firing.--              Unit-2, Asuka, be ready to the sortie for               covering. ',
#   "Misato : That's right. Take the rear guard ",
#   "Misato : It's being frozen by  Commander Ikari's absolute order.              (monologue )              (We must accept it after such an accident...)",
#   "Misato : Enemy's directional weapon ?   ",
#   'Misato : It is the order.             Asuka, I order you to retreat.',
#   "Misato : Transport Unit-0 by air ?             Shoot the target from sky ?             No, we can't do that.             If the Angel shoot Unit-0 during the approaching, we              can't protect.",
#   "Misato : But, there is the possibility that the contact of Adam and Eva             will cause the Third Impact.   That's too dangerous.              Commander Ikari, please do not do that !",
#   "Misato : (monologue)            (That isn't a true story?  That is a lie?             The Second Impact was not caused by the contact with Angel.)",
#   'Misato : You say the third impact will not be aroused by such a little             thing.   So, what is the real cause of the second impact ?',
#   "Misato:         The telephone which does not ring...        On BUSINESS        Sorry, but don't call me.",
#   "Misato:         I'll arrive 15 minutes later.                Launch Unit Zero from 32nd gate.                Set Unit Two to back-up (to cover).                No, I have no right to cancel the freeze of Unit One.                Ciao.",
#   "Misato:         I don't excuse.                Present status?",
#   "Misato:         Asuka, approach 300 more, and develop A.T. field,                fire the palette gun aiming at Target's back part.                Alright?                Eva Unit Two, Lift off!",
#   "Misato:         Sortie! Asuka! What's wrong?                Unit two's status?",
#   'Misato:         This way, she will be a victim.                Retrieve!                Immediately!',
#   'Misato:         The operation finished right now.                Move to the alert of the first kind.',
#   'Misato:         Although he must be lonely, maybe he fears a woman.                No, he fears the communication with people.',
#   "Misato:         I see, anybody will do.                It's me that is lonely.",
#   'Misato:         Hi, Hello, Eh? Really!                Shinji-kun!        The first Brain-Nerve',
#   "Misato:         I ain't irritated anymore by the telephone that does not ring,                since I received your mind.",
#   'Misato:         A tragedy of the people possessed by Eva.                I am also one of them.',
#   "Misato:         I see.                They found her 7 days after they missed her.                That isn't like them.",
#   'Misato:         Might be.                (And, today, the fifth will arrive for Asuka.                Too much arranged scenario.)',
#   'Misato:         Nagisa Kaoru (Kaoru of Seashore).                The record of his life has already been deleted, like Rei.',
#   'Misato:         Committee directly sent him to us.                He has something.',
#   "Misato:         Today I don't have any plan to cheat.                Let's see his capability.",
#   "Misato:         Nevertheless that's the fact.                We must accept the fact and then investigate the cause.",
#   "Misato:         Yet, we haven't yet known what he really is.                What is he, that boy?",
#   'Misato:         Shinji-kun has not yet returned.                I am disqualified as his guardian.',
#   "Misato:         We are lucky because we live in the suburb of the town.                You were not involved, I'm glad at that.                Yet, next time, I cannot garantee that.                So, you will be taken care at Horaki-san's from tomorrow.                So long, PenPen.",
#   "Misato:         I am sorry for that I made you do something like a thief.                What's this?",
#   'Misato:         Hmm, yes.                Mystery increases.                He can arrange any syncro ratio freely, at his own will.                We must do anything without considering how others see us.',
#   "Misato:         I don't care.                That boy, the Fifth is what?",
#   "Misato:         What's the hell!                Asuka a?",
#   "Misato:         Unmanned?                Isn't it the Fifth?",
#   'Misato:         Angel?                Is that boy?',
#   "Misato:         That's true. Accept the fact.                Sortie, Alright?",
#   'Misato:         When something happens after the signal from                 Unit One disappears,',
#   'Misato:         The one that takes care of you, and the one                that understands you is nobody but yourself.',
#   "Misato:         Everything is vague.                        That's freedom.",
#   'Misato:         The real figure that you conceive.                        That is the reality.',
#   "Misato:         Because you have no existence but of yourself,                You can't figure out your own shape.",
#   "Misato:         Yes. You are getting to know your own shape through                seeing others' shape.",
#   'Misato:         By cognizing the difference between you and others,                you form the image of yourself.',
#   'Misato:         Boys be glad! Today, I introduce you the transferee                everybody is talking about.',
#   'Misato:         Well, You are enjoying. I am curious as well.                Go ahead.'],
#  'Line Count': 350,
#  'Word Count': 6170}

# %%
# COMBINING NAMES

# had to look through spreadysheet to find typos

# converting to dataframe and exporting to excel sheet
df = pd.DataFrame(data=sorted_lines).T
df.columns = ['Lines','Linecount','Wordcount']
# df.to_excel('src/NGE_entire_series_lines_v2.xlsx')

df1 = pd.DataFrame(data=sorted_eps)
df1 = df1
# df1.to_excel('src/NGE_lines_by_episode_v2.xlsx')

# %%
# with pandas, we can very simply combine entire dataframes. for this analysis, I'm just going to compile typos for the
# top 10 characters + a couple other important ones from an old ranking poll

# merges all names in the list into the first name of the list in the df dataframe
def character_merge(list1):
    result = df.loc[list1[0]].copy()
    for name in list1[1:]:
        result += df.loc[name].copy()
    df.loc[list1[0]] = result
        
shinji_list = ['Shinji','Shiji',"Shinji'","Shinji '",'Shinji&Asuka']
asuka_list = ['Asuka','Little Asuka','Shinji&Asuka']
misato_list = ['Misato','Misato (thinking)','Mistato','Phone(Misato)']
ritsuko_list = ['Ritsuko','Ritusko','Ritsukko','Rituko']
ryoji_list = ['Ryoji','Ryouji','Ryouji (voice from the telephone)']
gendo_list = ['Gendo','Gendou','Gendow','Ikari']
fuyutsuki_list = ['Fuyutsuki','Fuyutsuki (voice)','Fuyutsuki(mono)','Fuyuzuki','Kouzou','Kozo','Kozou']

character_merge(shinji_list)
character_merge(asuka_list)
character_merge(misato_list)
character_merge(ritsuko_list)
character_merge(ryoji_list)
character_merge(gendo_list)
character_merge(fuyutsuki_list)

df.drop(['Shiji',"Shinji'","Shinji '",'Shinji&Asuka','Little Asuka','Shinji&Asuka','Misato (thinking)','Mistato',
         'Phone(Misato)','Ritusko','Ritsukko','Rituko','Ryouji','Ryouji (voice from the telephone)','Gendou',
         'Gendow','Fuyutsuki (voice)','Fuyutsuki(mono)','Fuyuzuki','Kouzou','Kozo','Kozou'], inplace=True)

df1.drop(['Shiji',"Shinji'","Shinji '",'Shinji&Asuka','Little Asuka','Shinji&Asuka','Misato (thinking)','Mistato',
         'Phone(Misato)','Ritusko','Ritsukko','Rituko','Ryouji','Ryouji (voice from the telephone)','Gendou',
         'Gendow','Fuyutsuki (voice)','Fuyutsuki(mono)','Fuyuzuki','Kouzou','Kozo','Kozou'], inplace=True)

# %%
df.loc['Shinji']
# Out:
# Lines        [Shinji: Out of order ... I shouldn't have com...
# Linecount                                                  237
# Wordcount                                                 3816
# Name: Shinji, dtype: object

# %%
# converting to dataframe and exporting to excel sheet
df.to_excel('src/NGE_entire_series_lines.xlsx')
df1.to_excel('src/NGE_lines_by_episode.xlsx')
